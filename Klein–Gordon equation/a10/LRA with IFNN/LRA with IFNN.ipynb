# %%
import tensorflow as tf
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from scipy.interpolate import griddata
from Klein_Gordon_model_tf import Sampler, Klein_Gordon
import scipy.io
# Out:
# D:\anaconda\envs\tf\lib\site-packages\tensorflow\python\framework\dtypes.py:526: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint8 = np.dtype([("qint8", np.int8, 1)])
# D:\anaconda\envs\tf\lib\site-packages\tensorflow\python\framework\dtypes.py:527: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_quint8 = np.dtype([("quint8", np.uint8, 1)])
# D:\anaconda\envs\tf\lib\site-packages\tensorflow\python\framework\dtypes.py:528: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint16 = np.dtype([("qint16", np.int16, 1)])
# D:\anaconda\envs\tf\lib\site-packages\tensorflow\python\framework\dtypes.py:529: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_quint16 = np.dtype([("quint16", np.uint16, 1)])
# D:\anaconda\envs\tf\lib\site-packages\tensorflow\python\framework\dtypes.py:530: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint32 = np.dtype([("qint32", np.int32, 1)])
# D:\anaconda\envs\tf\lib\site-packages\tensorflow\python\framework\dtypes.py:535: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   np_resource = np.dtype([("resource", np.ubyte, 1)])

# %%
import matplotlib as mpl
mpl.rcParams.update(mpl.rcParamsDefault)
np.random.seed(1236)
tf.set_random_seed(1236)

# %%
if __name__ == '__main__':
    def u(x):
        """
        :param x: x = (t, x)
        """
        return x[:, 1:2] * np.cos(10 * np.pi * x[:, 0:1]) + (x[:, 0:1] * x[:, 1:2])**3

    def u_tt(x):
        return - 100 * np.pi**2 * x[:, 1:2] * np.cos(10 * np.pi * x[:, 0:1]) + 6 * x[:,0:1] * x[:,1:2]**3

    def u_xx(x):
        return np.zeros((x.shape[0], 1)) +  6 * x[:,1:2] * x[:,0:1]**3

    def f(x, alpha, beta, gamma, k):
        return u_tt(x) + alpha * u_xx(x) + beta * u(x) + gamma * u(x)**k

    def operator(u, t, x, alpha, beta, gamma, k,  sigma_t=1.0, sigma_x=1.0):
        u_t = tf.gradients(u, t)[0] / sigma_t
        u_x = tf.gradients(u, x)[0] / sigma_x
        u_tt = tf.gradients(u_t, t)[0] / sigma_t
        u_xx = tf.gradients(u_x, x)[0] / sigma_x
        residual = u_tt + alpha * u_xx + beta * u + gamma * u**k
        return residual

    # Parameters of equations
    alpha = -1.0
    beta = 0.0
    gamma = 1.0
    k = 3

    # Domain boundaries
    ics_coords = np.array([[0.0, 0.0],
                           [0.0, 1.0]])
    bc1_coords = np.array([[0.0, 0.0],
                           [1.0, 0.0]])
    bc2_coords = np.array([[0.0, 1.0],
                           [1.0, 1.0]])
    dom_coords = np.array([[0.0, 0.0],
                           [1.0, 1.0]])

    # Create initial conditions samplers
    ics_sampler = Sampler(2, ics_coords, lambda x: u(x), name='Initial Condition 1')

    # Create boundary conditions samplers
    bc1 = Sampler(2, bc1_coords, lambda x: u(x), name='Dirichlet BC1')
    bc2 = Sampler(2, bc2_coords, lambda x: u(x), name='Dirichlet BC2')
    bcs_sampler = [bc1, bc2]

    # Create residual sampler
    res_sampler = Sampler(2, dom_coords, lambda x: f(x, alpha, beta, gamma, k), name='Forcing')

    # Define model
    layers = [2, 150, 150, 150, 150, 150, 1]
    mode = 'M4'          # Method: 'M1', 'M2', 'M3', 'M4'
    stiff_ratio = False  # Log the eigenvalues of Hessian of losses
    model = Klein_Gordon(layers, operator, ics_sampler, bcs_sampler, res_sampler, u,alpha, beta, gamma, k, mode, stiff_ratio)
# Out:
# WARNING:tensorflow:From D:\anaconda\envs\tf\lib\site-packages\tensorflow\python\framework\op_def_library.py:263: colocate_with (from tensorflow.python.framework.ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Colocations handled automatically by placer.
# WARNING:tensorflow:From D:\anaconda\envs\tf\lib\site-packages\tensorflow\python\ops\math_ops.py:3066: to_int32 (from tensorflow.python.ops.math_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use tf.cast instead.

# %%
    # Train model
    model.train(nIter=40001, batch_size=256)
# Out:
# It: 0, Loss: 1.691e+05, Loss_u: 1.348e+00, Loss_r: 1.691e+05, Time: 7.49
# constant_ics_val: 158.950, constant_bcs_val: 460.509
# Relative L2 error_u: 1.11e+00
# Gradients information stored ...
# It: 1000, Loss: 1.442e+03, Loss_u: 2.547e+02, Loss_r: 1.188e+03, Time: 168.05
# constant_ics_val: 146.965, constant_bcs_val: 440.398
# Relative L2 error_u: 1.02e+00
# It: 2000, Loss: 3.696e+01, Loss_u: 2.812e+00, Loss_r: 3.415e+01, Time: 137.67
# constant_ics_val: 134.974, constant_bcs_val: 445.184
# Relative L2 error_u: 2.95e-01
# It: 3000, Loss: 5.646e+01, Loss_u: 1.195e+01, Loss_r: 4.450e+01, Time: 134.36
# constant_ics_val: 124.096, constant_bcs_val: 620.093
# Relative L2 error_u: 1.72e-01
# It: 4000, Loss: 1.971e+01, Loss_u: 7.523e-01, Loss_r: 1.895e+01, Time: 134.02
# constant_ics_val: 118.293, constant_bcs_val: 640.320
# Relative L2 error_u: 1.62e-01
# It: 5000, Loss: 1.260e+01, Loss_u: 1.070e+00, Loss_r: 1.153e+01, Time: 135.44
# constant_ics_val: 109.165, constant_bcs_val: 675.629
# Relative L2 error_u: 1.36e-01
# It: 6000, Loss: 5.652e+01, Loss_u: 1.149e+00, Loss_r: 5.537e+01, Time: 134.87
# constant_ics_val: 105.340, constant_bcs_val: 686.472
# Relative L2 error_u: 9.98e-02
# It: 7000, Loss: 5.683e+00, Loss_u: 5.186e-01, Loss_r: 5.164e+00, Time: 135.49
# constant_ics_val: 97.975, constant_bcs_val: 734.522
# Relative L2 error_u: 8.85e-02
# It: 8000, Loss: 7.291e+00, Loss_u: 3.502e+00, Loss_r: 3.789e+00, Time: 161.96
# constant_ics_val: 89.888, constant_bcs_val: 893.852
# Relative L2 error_u: 7.74e-02
# It: 9000, Loss: 2.442e+00, Loss_u: 4.202e-01, Loss_r: 2.021e+00, Time: 190.94
# constant_ics_val: 82.966, constant_bcs_val: 895.025
# Relative L2 error_u: 6.87e-02
# It: 10000, Loss: 1.322e+01, Loss_u: 6.349e+00, Loss_r: 6.876e+00, Time: 212.70
# constant_ics_val: 75.333, constant_bcs_val: 923.688
# Relative L2 error_u: 5.76e-02
# Gradients information stored ...
# It: 11000, Loss: 2.203e+00, Loss_u: 2.195e-01, Loss_r: 1.983e+00, Time: 217.81
# constant_ics_val: 71.511, constant_bcs_val: 942.349
# Relative L2 error_u: 5.45e-02
# It: 12000, Loss: 4.005e+00, Loss_u: 1.090e+00, Loss_r: 2.916e+00, Time: 217.95
# constant_ics_val: 66.110, constant_bcs_val: 914.330
# Relative L2 error_u: 4.98e-02
# It: 13000, Loss: 1.635e+00, Loss_u: 6.229e-02, Loss_r: 1.572e+00, Time: 215.73
# constant_ics_val: 72.988, constant_bcs_val: 869.779
# Relative L2 error_u: 4.47e-02
# It: 14000, Loss: 1.372e+01, Loss_u: 8.697e+00, Loss_r: 5.026e+00, Time: 213.67
# constant_ics_val: 67.545, constant_bcs_val: 1214.889
# Relative L2 error_u: 4.24e-02
# It: 15000, Loss: 1.645e+00, Loss_u: 2.852e-01, Loss_r: 1.360e+00, Time: 215.18
# constant_ics_val: 63.406, constant_bcs_val: 1167.468
# Relative L2 error_u: 3.86e-02
# It: 16000, Loss: 1.099e+00, Loss_u: 4.146e-02, Loss_r: 1.058e+00, Time: 217.15
# constant_ics_val: 78.848, constant_bcs_val: 1131.997
# Relative L2 error_u: 3.57e-02
# It: 17000, Loss: 4.723e+00, Loss_u: 2.732e+00, Loss_r: 1.991e+00, Time: 217.30
# constant_ics_val: 72.567, constant_bcs_val: 1186.393
# Relative L2 error_u: 3.39e-02
# It: 18000, Loss: 4.826e-01, Loss_u: 6.865e-02, Loss_r: 4.140e-01, Time: 217.65
# constant_ics_val: 67.492, constant_bcs_val: 1114.093
# Relative L2 error_u: 3.09e-02
# It: 19000, Loss: 5.468e+00, Loss_u: 1.057e+00, Loss_r: 4.411e+00, Time: 217.10
# constant_ics_val: 61.799, constant_bcs_val: 1064.890
# Relative L2 error_u: 2.95e-02
# It: 20000, Loss: 8.256e-01, Loss_u: 5.271e-02, Loss_r: 7.729e-01, Time: 217.16
# constant_ics_val: 60.204, constant_bcs_val: 992.855
# Relative L2 error_u: 2.90e-02
# Gradients information stored ...
# It: 21000, Loss: 3.721e+00, Loss_u: 9.120e-01, Loss_r: 2.809e+00, Time: 218.09
# constant_ics_val: 57.374, constant_bcs_val: 1065.421
# Relative L2 error_u: 2.67e-02
# It: 22000, Loss: 4.841e-01, Loss_u: 1.088e-01, Loss_r: 3.753e-01, Time: 217.00
# constant_ics_val: 54.570, constant_bcs_val: 1021.285
# Relative L2 error_u: 2.53e-02
# It: 23000, Loss: 3.089e-01, Loss_u: 1.150e-02, Loss_r: 2.974e-01, Time: 216.90
# constant_ics_val: 61.680, constant_bcs_val: 982.653
# Relative L2 error_u: 2.39e-02
# It: 24000, Loss: 6.476e-01, Loss_u: 5.524e-02, Loss_r: 5.924e-01, Time: 216.53
# constant_ics_val: 57.852, constant_bcs_val: 943.369
# Relative L2 error_u: 2.34e-02
# It: 25000, Loss: 6.024e-01, Loss_u: 2.578e-02, Loss_r: 5.766e-01, Time: 216.26
# constant_ics_val: 57.593, constant_bcs_val: 896.769
# Relative L2 error_u: 2.21e-02
# It: 26000, Loss: 1.017e+00, Loss_u: 1.146e-01, Loss_r: 9.028e-01, Time: 216.38
# constant_ics_val: 55.738, constant_bcs_val: 1021.025
# Relative L2 error_u: 2.09e-02
# It: 27000, Loss: 3.264e-01, Loss_u: 7.231e-02, Loss_r: 2.541e-01, Time: 216.61
# constant_ics_val: 52.180, constant_bcs_val: 968.462
# Relative L2 error_u: 2.01e-02
# It: 28000, Loss: 8.664e-01, Loss_u: 1.724e-01, Loss_r: 6.941e-01, Time: 216.56
# constant_ics_val: 53.482, constant_bcs_val: 1156.854
# Relative L2 error_u: 2.00e-02
# It: 29000, Loss: 3.292e-01, Loss_u: 5.477e-02, Loss_r: 2.744e-01, Time: 215.58
# constant_ics_val: 50.020, constant_bcs_val: 1080.587
# Relative L2 error_u: 1.87e-02
# It: 30000, Loss: 1.825e+00, Loss_u: 8.373e-02, Loss_r: 1.741e+00, Time: 215.49
# constant_ics_val: 49.297, constant_bcs_val: 1012.967
# Relative L2 error_u: 2.00e-02
# Gradients information stored ...
# It: 31000, Loss: 2.641e-01, Loss_u: 4.350e-02, Loss_r: 2.206e-01, Time: 216.55
# constant_ics_val: 49.025, constant_bcs_val: 1050.620
# Relative L2 error_u: 1.81e-02
# It: 32000, Loss: 2.545e-01, Loss_u: 3.906e-02, Loss_r: 2.155e-01, Time: 216.35
# constant_ics_val: 46.132, constant_bcs_val: 1012.120
# Relative L2 error_u: 1.74e-02
# It: 33000, Loss: 2.059e-01, Loss_u: 1.216e-02, Loss_r: 1.938e-01, Time: 216.94
# constant_ics_val: 48.827, constant_bcs_val: 1059.029
# Relative L2 error_u: 1.72e-02
# It: 34000, Loss: 2.205e-01, Loss_u: 7.363e-03, Loss_r: 2.131e-01, Time: 217.45
# constant_ics_val: 65.619, constant_bcs_val: 1019.593
# Relative L2 error_u: 1.67e-02
# It: 35000, Loss: 2.575e-01, Loss_u: 1.165e-02, Loss_r: 2.458e-01, Time: 218.03
# constant_ics_val: 67.772, constant_bcs_val: 998.589
# Relative L2 error_u: 1.58e-02
# It: 36000, Loss: 1.663e-01, Loss_u: 1.160e-02, Loss_r: 1.547e-01, Time: 217.10
# constant_ics_val: 63.026, constant_bcs_val: 929.133
# Relative L2 error_u: 1.56e-02
# It: 37000, Loss: 2.493e-01, Loss_u: 1.852e-02, Loss_r: 2.308e-01, Time: 217.15
# constant_ics_val: 59.593, constant_bcs_val: 929.882
# Relative L2 error_u: 1.49e-02
# It: 38000, Loss: 2.400e-01, Loss_u: 2.420e-02, Loss_r: 2.158e-01, Time: 217.19
# constant_ics_val: 56.387, constant_bcs_val: 903.448
# Relative L2 error_u: 1.44e-02
# It: 39000, Loss: 1.549e-01, Loss_u: 8.114e-03, Loss_r: 1.467e-01, Time: 216.66
# constant_ics_val: 57.920, constant_bcs_val: 892.805
# Relative L2 error_u: 1.43e-02
# It: 40000, Loss: 1.291e-01, Loss_u: 5.351e-03, Loss_r: 1.238e-01, Time: 217.10
# constant_ics_val: 69.711, constant_bcs_val: 874.744
# Relative L2 error_u: 1.37e-02
# Gradients information stored ...

# %%
    # Test data
    nn = 100
    t = np.linspace(dom_coords[0, 0], dom_coords[1, 0], nn)[:, None]
    x = np.linspace(dom_coords[0, 1], dom_coords[1, 1], nn)[:, None]
    t, x = np.meshgrid(t, x)
    X_star = np.hstack((t.flatten()[:, None], x.flatten()[:, None]))

    # Exact solution
    u_star = u(X_star)
    f_star = f(X_star, alpha, beta, gamma, k)

    # Predictions
    u_pred = model.predict_u(X_star)

    error_u = np.linalg.norm(u_star - u_pred, 2) / np.linalg.norm(u_star, 2)
    print('Relative L2 error_u: {:.2e}'.format(error_u))
# Out:
# Relative L2 error_u: 1.37e-02

# %%
    # Test data
    U_star = griddata(X_star, u_star.flatten(), (t, x), method='cubic')
    F_star = griddata(X_star, f_star.flatten(), (t, x), method='cubic')

    U_pred = griddata(X_star, u_pred.flatten(), (t, x), method='cubic')

# %%
    fig_1 = plt.figure(1, figsize=(18, 5))
    plt.subplot(1, 3, 1)
    plt.pcolor(t, x, U_star, cmap='jet')
    plt.colorbar()
    plt.xlabel('$t$')
    plt.ylabel('$x$')
    plt.title('Exact u(x)')

    plt.subplot(1, 3, 2)
    plt.pcolor(t, x, U_pred, cmap='jet')
    plt.colorbar()
    plt.xlabel('$t$')
    plt.ylabel('$x$')
    plt.title('Predicted u(x)')

    plt.subplot(1, 3, 3)
    plt.pcolor(t, x, np.abs(U_star - U_pred), cmap='jet')
    plt.colorbar()
    plt.xlabel('$t$')
    plt.ylabel('$x$')
    plt.title('Absolute error')
    plt.tight_layout()
    plt.show()
# Out:
# D:\anaconda\envs\tf\lib\site-packages\ipykernel_launcher.py:3: MatplotlibDeprecationWarning: shading='flat' when X and Y have the same dimensions as C is deprecated since 3.3.  Either specify the corners of the quadrilaterals with X and Y, or pass shading='auto', 'nearest' or 'gouraud', or set rcParams['pcolor.shading'].  This will become an error two minor releases later.
#   This is separate from the ipykernel package so we can avoid doing imports until
# D:\anaconda\envs\tf\lib\site-packages\ipykernel_launcher.py:10: MatplotlibDeprecationWarning: shading='flat' when X and Y have the same dimensions as C is deprecated since 3.3.  Either specify the corners of the quadrilaterals with X and Y, or pass shading='auto', 'nearest' or 'gouraud', or set rcParams['pcolor.shading'].  This will become an error two minor releases later.
#   # Remove the CWD from sys.path while we load stuff.
# D:\anaconda\envs\tf\lib\site-packages\ipykernel_launcher.py:17: MatplotlibDeprecationWarning: shading='flat' when X and Y have the same dimensions as C is deprecated since 3.3.  Either specify the corners of the quadrilaterals with X and Y, or pass shading='auto', 'nearest' or 'gouraud', or set rcParams['pcolor.shading'].  This will become an error two minor releases later.

# %%
    l2_error = model.l2_error_log

# %%
scipy.io.savemat("1.mat", {'u': u_pred})

# %%
        iters = 1000 * np.arange(len(l2_error))
        plt.plot(iters, l2_error, label=r'$L^2$ error', linewidth=2)

        plt.yscale('log')
        plt.xlabel('iterations')
        plt.legend(loc='upper right', bbox_to_anchor=(1.0, 0.9), fontsize=20)
        plt.tight_layout()
        plt.show()

# %%
scipy.io.savemat("2.mat", {'l2': l2_error})
