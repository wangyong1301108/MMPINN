# %%
import tensorflow as tf
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from scipy.interpolate import griddata
from Klein_Gordon_model_tf import Sampler, Klein_Gordon
import scipy.io
# Out:
# D:\anaconda\envs\tf\lib\site-packages\tensorflow\python\framework\dtypes.py:526: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint8 = np.dtype([("qint8", np.int8, 1)])
# D:\anaconda\envs\tf\lib\site-packages\tensorflow\python\framework\dtypes.py:527: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_quint8 = np.dtype([("quint8", np.uint8, 1)])
# D:\anaconda\envs\tf\lib\site-packages\tensorflow\python\framework\dtypes.py:528: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint16 = np.dtype([("qint16", np.int16, 1)])
# D:\anaconda\envs\tf\lib\site-packages\tensorflow\python\framework\dtypes.py:529: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_quint16 = np.dtype([("quint16", np.uint16, 1)])
# D:\anaconda\envs\tf\lib\site-packages\tensorflow\python\framework\dtypes.py:530: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint32 = np.dtype([("qint32", np.int32, 1)])
# D:\anaconda\envs\tf\lib\site-packages\tensorflow\python\framework\dtypes.py:535: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   np_resource = np.dtype([("resource", np.ubyte, 1)])

# %%
import matplotlib as mpl
mpl.rcParams.update(mpl.rcParamsDefault)
np.random.seed(1235)
tf.set_random_seed(1235)

# %%
if __name__ == '__main__':
    def u(x):
        """
        :param x: x = (t, x)
        """
        return x[:, 1:2] * np.cos(10 * np.pi * x[:, 0:1]) + (x[:, 0:1] * x[:, 1:2])**3

    def u_tt(x):
        return - 100 * np.pi**2 * x[:, 1:2] * np.cos(10 * np.pi * x[:, 0:1]) + 6 * x[:,0:1] * x[:,1:2]**3

    def u_xx(x):
        return np.zeros((x.shape[0], 1)) +  6 * x[:,1:2] * x[:,0:1]**3

    def f(x, alpha, beta, gamma, k):
        return u_tt(x) + alpha * u_xx(x) + beta * u(x) + gamma * u(x)**k

    def operator(u, t, x, alpha, beta, gamma, k,  sigma_t=1.0, sigma_x=1.0):
        u_t = tf.gradients(u, t)[0] / sigma_t
        u_x = tf.gradients(u, x)[0] / sigma_x
        u_tt = tf.gradients(u_t, t)[0] / sigma_t
        u_xx = tf.gradients(u_x, x)[0] / sigma_x
        residual = u_tt + alpha * u_xx + beta * u + gamma * u**k
        return residual

    # Parameters of equations
    alpha = -1.0
    beta = 0.0
    gamma = 1.0
    k = 3

    # Domain boundaries
    ics_coords = np.array([[0.0, 0.0],
                           [0.0, 1.0]])
    bc1_coords = np.array([[0.0, 0.0],
                           [1.0, 0.0]])
    bc2_coords = np.array([[0.0, 1.0],
                           [1.0, 1.0]])
    dom_coords = np.array([[0.0, 0.0],
                           [1.0, 1.0]])

    # Create initial conditions samplers
    ics_sampler = Sampler(2, ics_coords, lambda x: u(x), name='Initial Condition 1')

    # Create boundary conditions samplers
    bc1 = Sampler(2, bc1_coords, lambda x: u(x), name='Dirichlet BC1')
    bc2 = Sampler(2, bc2_coords, lambda x: u(x), name='Dirichlet BC2')
    bcs_sampler = [bc1, bc2]

    # Create residual sampler
    res_sampler = Sampler(2, dom_coords, lambda x: f(x, alpha, beta, gamma, k), name='Forcing')

    # Define model
    layers = [ 150, 150, 150, 150, 150, 1]
    mode = 'M5'          # Method: 'M1', 'M2', 'M3', 'M4'
    stiff_ratio = False  # Log the eigenvalues of Hessian of losses
    model = Klein_Gordon(layers, operator, ics_sampler, bcs_sampler, res_sampler, u,alpha, beta, gamma, k, mode, stiff_ratio)
# Out:
# WARNING:tensorflow:From D:\anaconda\envs\tf\lib\site-packages\tensorflow\python\framework\op_def_library.py:263: colocate_with (from tensorflow.python.framework.ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Colocations handled automatically by placer.
# WARNING:tensorflow:From D:\anaconda\envs\tf\lib\site-packages\tensorflow\python\ops\math_ops.py:3066: to_int32 (from tensorflow.python.ops.math_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use tf.cast instead.

# %%
    # Train model
    model.train(nIter=40001, batch_size=256)
# Out:
# It: 0, Loss: 6.052e+01, Loss_u: 5.317e+01, Loss_r: 1.829e+05, Time: 27.74
# constant_ics_val: 1.000, constant_bcs_val: 1.000
# Relative L2 error_u: 2.53e+00
# Gradients information stored ...
# It: 1000, Loss: 3.924e+00, Loss_u: 1.978e-02, Loss_r: 4.876e+01, Time: 662.62
# constant_ics_val: 1.000, constant_bcs_val: 1.000
# Relative L2 error_u: 6.14e-02
# It: 2000, Loss: 2.804e+00, Loss_u: 4.620e-02, Loss_r: 1.462e+01, Time: 650.99
# constant_ics_val: 1.000, constant_bcs_val: 1.000
# Relative L2 error_u: 2.94e-02
# It: 3000, Loss: 2.235e+00, Loss_u: 3.672e-02, Loss_r: 6.889e+00, Time: 654.39
# constant_ics_val: 1.000, constant_bcs_val: 1.000
# Relative L2 error_u: 2.57e-02
# It: 4000, Loss: 1.854e+00, Loss_u: 2.718e-04, Loss_r: 5.732e+00, Time: 654.97
# constant_ics_val: 1.000, constant_bcs_val: 1.000
# Relative L2 error_u: 1.52e-02
# It: 5000, Loss: 1.568e+00, Loss_u: 6.505e-03, Loss_r: 2.637e+00, Time: 652.68
# constant_ics_val: 1.000, constant_bcs_val: 1.000
# Relative L2 error_u: 1.21e-02
# It: 6000, Loss: 1.504e+00, Loss_u: 6.824e-04, Loss_r: 2.836e+00, Time: 653.75
# constant_ics_val: 1.000, constant_bcs_val: 1.000
# Relative L2 error_u: 1.50e-02
# It: 7000, Loss: 1.585e+00, Loss_u: 1.721e-02, Loss_r: 2.335e+00, Time: 653.34
# constant_ics_val: 1.000, constant_bcs_val: 1.000
# Relative L2 error_u: 1.55e-02
# It: 8000, Loss: 1.175e+00, Loss_u: 6.443e-05, Loss_r: 1.462e+00, Time: 654.29
# constant_ics_val: 1.000, constant_bcs_val: 1.000
# Relative L2 error_u: 1.01e-02
# It: 9000, Loss: 1.435e+00, Loss_u: 9.875e-05, Loss_r: 2.678e+00, Time: 654.00
# constant_ics_val: 1.000, constant_bcs_val: 1.000
# Relative L2 error_u: 1.23e-02
# It: 10000, Loss: 1.382e+00, Loss_u: 2.345e-04, Loss_r: 2.302e+00, Time: 654.03
# constant_ics_val: 1.000, constant_bcs_val: 1.000
# Relative L2 error_u: 9.03e-03
# Gradients information stored ...
# It: 11000, Loss: 9.133e-01, Loss_u: 8.382e-04, Loss_r: 5.493e-01, Time: 654.77
# constant_ics_val: 1.000, constant_bcs_val: 1.000
# Relative L2 error_u: 7.49e-03
# It: 12000, Loss: 1.086e+00, Loss_u: 3.220e-03, Loss_r: 8.265e-01, Time: 653.14
# constant_ics_val: 1.000, constant_bcs_val: 1.000
# Relative L2 error_u: 5.84e-03
# It: 13000, Loss: 6.524e-01, Loss_u: 3.465e-05, Loss_r: 2.381e-01, Time: 655.70
# constant_ics_val: 1.000, constant_bcs_val: 1.000
# Relative L2 error_u: 4.44e-03
# It: 14000, Loss: 9.043e-01, Loss_u: 1.804e-03, Loss_r: 4.792e-01, Time: 656.45
# constant_ics_val: 1.000, constant_bcs_val: 1.000
# Relative L2 error_u: 3.50e-03
# It: 15000, Loss: 8.709e-01, Loss_u: 4.693e-04, Loss_r: 4.989e-01, Time: 651.49
# constant_ics_val: 1.000, constant_bcs_val: 1.000
# Relative L2 error_u: 4.52e-03
# It: 16000, Loss: 7.261e-01, Loss_u: 9.325e-05, Loss_r: 3.154e-01, Time: 653.37
# constant_ics_val: 1.000, constant_bcs_val: 1.000
# Relative L2 error_u: 5.05e-03
# It: 17000, Loss: 7.265e-01, Loss_u: 4.214e-04, Loss_r: 2.766e-01, Time: 653.27
# constant_ics_val: 1.000, constant_bcs_val: 1.000
# Relative L2 error_u: 3.79e-03
# It: 18000, Loss: 6.335e-01, Loss_u: 8.571e-05, Loss_r: 2.048e-01, Time: 654.91
# constant_ics_val: 1.000, constant_bcs_val: 1.000
# Relative L2 error_u: 3.05e-03
# It: 19000, Loss: 5.441e-01, Loss_u: 8.184e-05, Loss_r: 1.255e-01, Time: 648.70
# constant_ics_val: 1.000, constant_bcs_val: 1.000
# Relative L2 error_u: 3.49e-03
# It: 20000, Loss: 5.109e-01, Loss_u: 9.680e-05, Loss_r: 1.005e-01, Time: 649.77
# constant_ics_val: 1.000, constant_bcs_val: 1.000
# Relative L2 error_u: 3.30e-03
# Gradients information stored ...
# It: 21000, Loss: 4.132e-01, Loss_u: 2.754e-05, Loss_r: 5.618e-02, Time: 653.38
# constant_ics_val: 1.000, constant_bcs_val: 1.000
# Relative L2 error_u: 2.02e-03
# It: 22000, Loss: 5.360e-01, Loss_u: 4.103e-05, Loss_r: 1.262e-01, Time: 650.61
# constant_ics_val: 1.000, constant_bcs_val: 1.000
# Relative L2 error_u: 1.74e-03
# It: 23000, Loss: 4.544e-01, Loss_u: 6.214e-06, Loss_r: 8.290e-02, Time: 650.82
# constant_ics_val: 1.000, constant_bcs_val: 1.000
# Relative L2 error_u: 1.75e-03
# It: 24000, Loss: 3.564e-01, Loss_u: 3.495e-05, Loss_r: 3.393e-02, Time: 650.37
# constant_ics_val: 1.000, constant_bcs_val: 1.000
# Relative L2 error_u: 1.53e-03
# It: 25000, Loss: 4.067e-01, Loss_u: 6.515e-05, Loss_r: 4.921e-02, Time: 636.86
# constant_ics_val: 1.000, constant_bcs_val: 1.000
# Relative L2 error_u: 1.25e-03
# It: 26000, Loss: 3.381e-01, Loss_u: 1.308e-06, Loss_r: 3.501e-02, Time: 552.70
# constant_ics_val: 1.000, constant_bcs_val: 1.000
# Relative L2 error_u: 1.30e-03
# It: 27000, Loss: 3.175e-01, Loss_u: 9.603e-05, Loss_r: 2.005e-02, Time: 552.61
# constant_ics_val: 1.000, constant_bcs_val: 1.000
# Relative L2 error_u: 1.10e-03
# It: 28000, Loss: 3.245e-01, Loss_u: 7.325e-06, Loss_r: 2.839e-02, Time: 553.90
# constant_ics_val: 1.000, constant_bcs_val: 1.000
# Relative L2 error_u: 1.27e-03
# It: 29000, Loss: 3.231e-01, Loss_u: 1.097e-04, Loss_r: 2.085e-02, Time: 552.94
# constant_ics_val: 1.000, constant_bcs_val: 1.000
# Relative L2 error_u: 1.21e-03
# It: 30000, Loss: 3.235e-01, Loss_u: 1.600e-05, Loss_r: 2.654e-02, Time: 554.49
# constant_ics_val: 1.000, constant_bcs_val: 1.000
# Relative L2 error_u: 1.09e-03
# Gradients information stored ...
# It: 31000, Loss: 3.264e-01, Loss_u: 1.135e-05, Loss_r: 2.807e-02, Time: 553.43
# constant_ics_val: 1.000, constant_bcs_val: 1.000
# Relative L2 error_u: 1.08e-03
# It: 32000, Loss: 2.214e-01, Loss_u: 1.753e-05, Loss_r: 7.459e-03, Time: 550.95
# constant_ics_val: 1.000, constant_bcs_val: 1.000
# Relative L2 error_u: 7.07e-04
# It: 33000, Loss: 2.507e-01, Loss_u: 5.743e-05, Loss_r: 9.549e-03, Time: 551.75
# constant_ics_val: 1.000, constant_bcs_val: 1.000
# Relative L2 error_u: 8.09e-04
# It: 34000, Loss: 1.967e-01, Loss_u: 5.156e-06, Loss_r: 5.772e-03, Time: 550.49
# constant_ics_val: 1.000, constant_bcs_val: 1.000
# Relative L2 error_u: 8.83e-04
# It: 35000, Loss: 1.997e-01, Loss_u: 1.798e-06, Loss_r: 6.594e-03, Time: 550.36
# constant_ics_val: 1.000, constant_bcs_val: 1.000
# Relative L2 error_u: 7.18e-04
# It: 36000, Loss: 1.610e-01, Loss_u: 1.134e-05, Loss_r: 2.656e-03, Time: 550.60
# constant_ics_val: 1.000, constant_bcs_val: 1.000
# Relative L2 error_u: 6.20e-04
# It: 37000, Loss: 1.448e-01, Loss_u: 1.128e-06, Loss_r: 2.427e-03, Time: 514.25
# constant_ics_val: 1.000, constant_bcs_val: 1.000
# Relative L2 error_u: 5.59e-04
# It: 38000, Loss: 1.622e-01, Loss_u: 8.704e-06, Loss_r: 2.839e-03, Time: 458.96
# constant_ics_val: 1.000, constant_bcs_val: 1.000
# Relative L2 error_u: 5.97e-04
# It: 39000, Loss: 1.305e-01, Loss_u: 9.418e-07, Loss_r: 1.760e-03, Time: 458.35
# constant_ics_val: 1.000, constant_bcs_val: 1.000
# Relative L2 error_u: 5.38e-04
# It: 40000, Loss: 1.174e-01, Loss_u: 6.504e-07, Loss_r: 1.286e-03, Time: 396.01
# constant_ics_val: 1.000, constant_bcs_val: 1.000
# Relative L2 error_u: 5.03e-04
# Gradients information stored ...

# %%
    # Test data
    nn = 100
    t = np.linspace(dom_coords[0, 0], dom_coords[1, 0], nn)[:, None]
    x = np.linspace(dom_coords[0, 1], dom_coords[1, 1], nn)[:, None]
    t, x = np.meshgrid(t, x)
    X_star = np.hstack((t.flatten()[:, None], x.flatten()[:, None]))

    # Exact solution
    u_star = u(X_star)
    f_star = f(X_star, alpha, beta, gamma, k)

    # Predictions
    u_pred = model.predict_u(X_star)

    error_u = np.linalg.norm(u_star - u_pred, 2) / np.linalg.norm(u_star, 2)
    print('Relative L2 error_u: {:.2e}'.format(error_u))
# Out:
# Relative L2 error_u: 5.03e-04

# %%
    print('Relative L2 error_u: {:.3e}'.format(error_u))
# Out:
# Relative L2 error_u: 5.029e-04

# %%
    # Test data
    U_star = griddata(X_star, u_star.flatten(), (t, x), method='cubic')
    F_star = griddata(X_star, f_star.flatten(), (t, x), method='cubic')

    U_pred = griddata(X_star, u_pred.flatten(), (t, x), method='cubic')

# %%
    fig_1 = plt.figure(1, figsize=(18, 5))
    plt.subplot(1, 3, 1)
    plt.pcolor(t, x, U_star, cmap='jet')
    plt.colorbar()
    plt.xlabel('$t$')
    plt.ylabel('$x$')
    plt.title('Exact u(x)')

    plt.subplot(1, 3, 2)
    plt.pcolor(t, x, U_pred, cmap='jet')
    plt.colorbar()
    plt.xlabel('$t$')
    plt.ylabel('$x$')
    plt.title('Predicted u(x)')

    plt.subplot(1, 3, 3)
    plt.pcolor(t, x, np.abs(U_star - U_pred), cmap='jet')
    plt.colorbar()
    plt.xlabel('$t$')
    plt.ylabel('$x$')
    plt.title('Absolute error')
    plt.tight_layout()
    plt.show()
# Out:
# D:\anaconda\envs\tf\lib\site-packages\ipykernel_launcher.py:3: MatplotlibDeprecationWarning: shading='flat' when X and Y have the same dimensions as C is deprecated since 3.3.  Either specify the corners of the quadrilaterals with X and Y, or pass shading='auto', 'nearest' or 'gouraud', or set rcParams['pcolor.shading'].  This will become an error two minor releases later.
#   This is separate from the ipykernel package so we can avoid doing imports until
# D:\anaconda\envs\tf\lib\site-packages\ipykernel_launcher.py:10: MatplotlibDeprecationWarning: shading='flat' when X and Y have the same dimensions as C is deprecated since 3.3.  Either specify the corners of the quadrilaterals with X and Y, or pass shading='auto', 'nearest' or 'gouraud', or set rcParams['pcolor.shading'].  This will become an error two minor releases later.
#   # Remove the CWD from sys.path while we load stuff.
# D:\anaconda\envs\tf\lib\site-packages\ipykernel_launcher.py:17: MatplotlibDeprecationWarning: shading='flat' when X and Y have the same dimensions as C is deprecated since 3.3.  Either specify the corners of the quadrilaterals with X and Y, or pass shading='auto', 'nearest' or 'gouraud', or set rcParams['pcolor.shading'].  This will become an error two minor releases later.

# %%
scipy.io.savemat("1.mat", {'u': u_pred})

# %%
    l2_error = model.l2_error_log

# %%
        iters = 1000 * np.arange(len(l2_error))
        plt.plot(iters, l2_error, label=r'$L^2$ error', linewidth=2)

        plt.yscale('log')
        plt.xlabel('iterations')
        plt.legend(loc='upper right', bbox_to_anchor=(1.0, 0.9), fontsize=20)
        plt.tight_layout()
        plt.show()

# %%
scipy.io.savemat("2.mat", {'l2': l2_error})
